# %% [markdown]
# # Nvidia SMI

# %%
# import time
# import subprocess
# from IPython.display import clear_output

# def color(text, code):
#     return f"\033[{code}m{text}\033[0m"

# def get_color(val, low=40, high=80):
#     if val > high:
#         return "31"  # red
#     elif val > low:
#         return "33"  # yellow
#     else:
#         return "32"  # green

# def bar(val, length=20):
#     filled = int(val / 100 * length)
#     return "█" * filled + "-" * (length - filled)


# count =  0
# time_limit = 5

# while time_limit is None or count <= time_limit:
#     clear_output(wait=True)

#     result = subprocess.check_output([
#         "nvidia-smi",
#         "--query-gpu=name,utilization.gpu,utilization.memory,memory.used,memory.total,temperature.gpu",
#         "--format=csv,noheader,nounits"
#     ]).decode().strip().split("\n")

#     print(color("=== GPU MONITOR ===", "34"))
#     print()

#     for line in result:
#         name, gpu, mem_util, mem_used, mem_total, temp = [x.strip() for x in line.split(",")]

#         gpu = int(gpu)
#         temp = int(temp)
#         mem_used = int(mem_used)
#         mem_total = int(mem_total)
#         mem_pct = int(mem_used / mem_total * 100)

#         gpu_c = get_color(gpu)
#         temp_c = get_color(temp, 60, 80)

#         print(color(name, "36"))
#         print(f"  GPU:   {color(f'{gpu:3d}%', gpu_c)} [{bar(gpu)}]")
#         print(f"  VRAM:  {mem_used}/{mem_total} MB ({mem_pct}%) [{bar(mem_pct)}]")
#         print(f"  Temp:  {color(f'{temp}°C', temp_c)}")
#         print()

#     time.sleep(1)
#     count += 1

# %%
# %%sh
# #!/bin/bash

# # ===============================
# # 🎨 NVIDIA GPU Comprehensive Dashboard
# # ===============================

# # Colors
# RED='\033[0;31m'
# YELLOW='\033[1;33m'
# GREEN='\033[0;32m'
# BLUE='\033[0;34m'
# CYAN='\033[0;36m'
# NC='\033[0m'

# # Function to create a usage bar
# bar() {
#     local val=$1
#     local len=20
#     local filled=$((val * len / 100))
#     local empty=$((len - filled))
#     printf "%0.s█" $(seq 1 $filled)
#     printf "%0.s-" $(seq 1 $empty)
# }

# while true; do
#     clear
#     echo -e "${BLUE}=== NVIDIA GPU DASHBOARD ===${NC}"
#     echo -e "$(date)"
#     echo

#     # Query GPU info
#     nvidia-smi --query-gpu=index,name,utilization.gpu,utilization.memory,memory.used,memory.total,temperature.gpu,power.draw \
#     --format=csv,noheader,nounits | while IFS=',' read -r idx name gpu_util mem_util mem_used mem_total temp power; do
#         idx=$(echo $idx | xargs)
#         name=$(echo $name | xargs)
#         gpu_util=$(echo $gpu_util | xargs)
#         mem_util=$(echo $mem_util | xargs)
#         mem_used=$(echo $mem_used | xargs)
#         mem_total=$(echo $mem_total | xargs)
#         temp=$(echo $temp | xargs)
#         power=$(echo $power | xargs)

#         # Colors for GPU usage
#         if [ "$gpu_util" -gt 80 ]; then gpu_color=$RED
#         elif [ "$gpu_util" -gt 40 ]; then gpu_color=$YELLOW
#         else gpu_color=$GREEN
#         fi

#         # Colors for temperature
#         if [ "$temp" -gt 85 ]; then temp_color=$RED
#         elif [ "$temp" -gt 70 ]; then temp_color=$YELLOW
#         else temp_color=$GREEN
#         fi

#         # Memory %
#         mem_pct=$((mem_used * 100 / mem_total))

#         # Print GPU info
#         echo -e "${CYAN}GPU $idx: $name${NC}"
#         echo -e "  GPU Usage: ${gpu_color}$gpu_util%${NC} [$(bar $gpu_util)]"
#         echo -e "  Memory:    $mem_used/$mem_total MB ($mem_pct%) [$(bar $mem_pct)]"
#         echo -e "  Temp:      ${temp_color}$temp°C${NC}"
#         if [[ "$power" == "N/A" ]]; then
#             echo -e "  Power:     ${YELLOW}N/A${NC}"
#         else
#             echo -e "  Power:     $power W"
#         fi

#         # Show processes on this GPU
#         echo "  Processes:"
#         nvidia-smi --query-compute-apps=pid,process_name,used_memory --format=csv,noheader,nounits | \
#         while IFS=',' read -r pid pname p_mem; do
#             # highlight heavy VRAM users
#             if [ "$p_mem" -gt 2000 ]; then color=$RED
#             else color=$GREEN
#             fi
#             echo -e "    - $pname (PID $pid): ${color}$p_mem MB${NC}"
#         done
#         echo
#     done

#     sleep 1
# done

# %% [markdown]
# # Models

# %%
# %%sh
# hf download openai/gpt-oss-20b --local-dir /workspaces/chris/data/llms/gpt-oss-20b --token $HF_READ_TOKEN

# %% [markdown]
# # Finetuning

# %%
# %pip install --force-reinstall --upgrade transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.17 (from transformers)
#   Downloading numpy-2.4.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting packaging>=20.0 (from transformers)
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.1.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting click>=8.2.1 (from typer->transformers)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=12.3.0->typer->transformers)
#   Downloading pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 54.0 MB/s  0:00:00
# Downloading huggingface_hub-1.9.0-py3-none-any.whl (637 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 637.4/637.4 kB 27.5 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 54.9 MB/s  0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 60.9 MB/s  0:00:00
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading numpy-2.4.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 59.0 MB/s  0:00:00 eta 0:00:01
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 32.1 MB/s  0:00:00
# Downloading regex-2026.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (799 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.8/799.8 kB 32.4 MB/s  0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.6 MB/s  0:00:00
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: typing-extensions, tqdm, shellingham, safetensors, regex, pyyaml, pygments, packaging, numpy, mdurl, idna, hf-xet, h11, fsspec, filelock, click, certifi, annotated-doc, markdown-it-py, httpcore, anyio, rich, httpx, typer, huggingface-hub, tokenizers, transformers
#   WARNING: The script tqdm is installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/27 [pygments]  WARNING: The script pygmentize is installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/27 [numpy]ing]  WARNING: The scripts f2py and numpy-config are installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 17/27 [annotated-doc]  WARNING: The script markdown-it is installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 21/27 [rich]  WARNING: The script httpx is installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer is installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 24/27 [huggingface-hub]  WARNING: The scripts hf and tiny-agents are installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 26/27 [transformers]  WARNING: The script transformers is installed in '/home/devuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 2.13.0 requires numpy<2, but you have numpy 2.4.4 which is incompatible.
# mlflow 2.13.0 requires packaging<25, but you have packaging 26.0 which is incompatible.
# datasets 2.20.0 requires fsspec[http]<=2024.5.0,>=2023.1.0, but you have fsspec 2026.3.0 which is incompatible.
# pyarrow 15.0.2 requires numpy<2,>=1.16.6, but you have numpy 2.4.4 which is incompatible.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.4.4 which is incompatible.
# Successfully installed annotated-doc-0.0.4 anyio-4.13.0 certifi-2026.2.25 click-8.3.2 filelock-3.25.2 fsspec-2026.3.0 h11-0.16.0 hf-xet-1.4.3 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.9.0 idna-3.11 markdown-it-py-4.0.0 mdurl-0.1.2 numpy-2.4.4 packaging-26.0 pygments-2.20.0 pyyaml-6.0.3 regex-2026.4.4 rich-14.3.3 safetensors-0.7.0 shellingham-1.5.4 tokenizers-0.22.2 tqdm-4.67.3 transformers-5.5.0 typer-0.24.1 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# from datasets import load_dataset
from transformers import AutoTokenizer, DataCollatorForLanguageModeling
from transformers import AutoModelForCausalLM, TrainingArguments, Trainer
# Out:
# Disabling PyTorch because PyTorch >= 2.4 is required but found 2.3.0
# PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# /home/devuser/.local/lib/python3.11/site-packages/transformers/data/metrics/__init__.py:19: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.4.4)
#   from scipy.stats import pearsonr, spearmanr

# %%
model_name = "/workspace/src/data/llms/gpt-oss-20b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# dataset = load_dataset("karthiksagarn/astro_horoscope", split="train")

# %%
def tokenize(batch):
    return tokenizer(
        batch["horoscope"],
        truncation=True,
        max_length=512,
    )

dataset = dataset.map(tokenize, batched=True, remove_columns=dataset.column_names)
dataset = dataset.train_test_split(test_size=0.1)

# %%
training_args = TrainingArguments(
    output_dir="/workspaces/chris/data/finetuning/gpt-oss-20b'",
    num_train_epochs=3,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=8,
    gradient_checkpointing=True,
    bf16=True,
    learning_rate=2e-5,
    logging_steps=10,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
)

# %%
import torch

# %%
# %%sh
# nvidia-smi --version

# %%
model = AutoModelForCausalLM.from_pretrained(model_name, dtype="auto")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = AutoModelForCausalLM.from_pretrained(model_name, dtype="auto")
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2035, in DummyObject.__getattribute__(cls, key)
#    2033 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2034     return super().__getattribute__(key)
# -> 2035 requires_backends(cls, cls._backends)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2021, in requires_backends(obj, backends)
#    2018         failed.append(msg.format(name))
#    2020 if failed:
# -> 2021     raise ImportError("".join(failed))
#
# ImportError:
# AutoModelForCausalLM requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    processing_class=tokenizer,
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False),
)

trainer.train()
